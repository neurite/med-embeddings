# %%
import pandas as pd
from pandas import DataFrame
from sklearn.utils import shuffle

# %% [markdown]
# Will perform the following:
#
# 1. Merge text from different columns together. The merged data frame will have 3 columns:
#
#     ```
#     ['label', 'text', 'source']
#     ```
#
# 2. Minimal normalization of converting to lower case and stripping whitespace
# 3. Shuffle the merged data
#
# Let's not be agressive with normalization. Only upper case to lower case.
#
# Some observations when considering normalization:
#
# * 2-Amino-4,6-pteridinediol
# * Ser/Plas
# * [Moles/volume]
# * {Setting}
# * Pulmonary vein - right upper
# * Multisection^W contrast IV
# * Bacteria identified^^^2
# * ^Patient
# * Blood flow.diastole.max
# * Upper extremity>Upper arm
# * A+B Ag

# %%
def rename_columns(df, label_col, text_col):
    """

    Renames the selected label column to 'label' and
    the text column to 'text'. Adds a new column 'source'
    indicating the source.

    df: DataFrame
    label_col: string, the label column
    text_col: string, the text column
    return: a new data frame with columns renamed

    """
    df = df.rename(index=str, columns={
        label_col: 'label',
        text_col: 'text'
    })
    df['source'] = text_col
    return df

# %%
def normalize(df):
    """

    Adds a normalized text column 'text_normed'. Normalization is lightweight
    only converting to lower case and stripping whitespace.

    df: DataFrame
    return: void, adding a new column

    """
    df['text_normed'] = df['text'].apply(lambda x: str(x).lower().strip())

# %%
def merge(df_dicts):
    """
    dataframes: list of data frame dict {df, label_col, text_col}
    return: the merged, normalized, shuffled data frame
    """
    # Merge data frames
    dfs = []
    for df_dict in df_dicts:
        df = df_dict['df']
        label_col = df_dict['label_col']
        text_col = df_dict['text_col']
        df = rename_columns(df, label_col, text_col)
        dfs.append(df)
    df_merged = pd.concat(dfs, ignore_index=True)
    # Drop duplicates
    df_merged = df_merged.drop_duplicates()
    # Normalize text
    normalize(df_merged)
    # Drop rows that has null and empty text
    # Pandas gotcha, missing values internally as NaN, python 'is not None' won't work
    df_merged = df_merged[df_merged['text'].notnull()]
    df_merged = df_merged[df_merged['text_normed'].map(lambda text: len(text) > 0)]
    # Shuffle
    df_merged = shuffle(df_merged)
    return df_merged

# %% [markdown]
# ### Merge all the candidate columns

# %%
df_component = pd.read_csv('data/loinc-component.csv')
df_short_name = pd.read_csv('data/loinc-short-name.csv')
df_long_name = pd.read_csv('data/loinc-long-name.csv')
df_system = pd.read_csv('data/loinc-system.csv')
df_class = pd.read_csv('data/loinc-class.csv')
df_related = pd.read_csv('data/loinc-related-name.csv')

# %%
df_dicts = [
    {
        'df': df_component,
        'label_col': 'LOINC_NUM',
        'text_col': 'COMPONENT'
    }, {
        'df': df_short_name,
        'label_col': 'LOINC_NUM',
        'text_col': 'SHORTNAME'
    }, {
        'df': df_long_name,
        'label_col': 'LOINC_NUM',
        'text_col': 'LONG_COMMON_NAME'
    }, {
        'df': df_system,
        'label_col': 'LOINC_NUM',
        'text_col': 'SYSTEM'
    }, {
        'df': df_class,
        'label_col': 'LOINC_NUM',
        'text_col': 'CLASS'
    }, {
        'df': df_related,
        'label_col': 'LOINC_NUM',
        'text_col': 'RELATED_NAME'
    }
]

# %%
df_merged_all = merge(df_dicts)

# %%
df_merged_all.sample(10)
# Out:
#            label                                      text        source  \
# 2012842    773-2                                 Red cells  RELATED_NAME
# 1432461  49975-6                                       Blt  RELATED_NAME
# 1796856  67215-4                                    Screen  RELATED_NAME
# 636332    1875-4                                     Level  RELATED_NAME
# 1314882  45316-7                                 Chemistry  RELATED_NAME
# 685880    2064-4                           Serum or plasma  RELATED_NAME
# 1321524  46509-6  International Classification of Diseases  RELATED_NAME
# 1046423  34717-9                                        FA  RELATED_NAME
# 1401847  49028-4                                    Random  RELATED_NAME
# 480728   12642-5                             Point in time  RELATED_NAME
#
#                                       text_normed
# 2012842                                 red cells
# 1432461                                       blt
# 1796856                                    screen
# 636332                                      level
# 1314882                                 chemistry
# 685880                            serum or plasma
# 1321524  international classification of diseases
# 1046423                                        fa
# 1401847                                    random
# 480728                              point in time

# %%
df_merged_all.shape
# Out:
# (2198746, 4)

# %% [markdown]
# ### Merge only the columns of long names and short names

# %%
df_dicts = [
    {
        'df': df_short_name,
        'label_col': 'LOINC_NUM',
        'text_col': 'SHORTNAME'
    }, {
        'df': df_long_name,
        'label_col': 'LOINC_NUM',
        'text_col': 'LONG_COMMON_NAME'
    }
]

# %%
df_merged_names = merge(df_dicts)

# %%
df_merged_names.sample(5)
# Out:
#           label                                               text  \
# 89637   15580-4   Blackberry IgE Ab RAST class [Presence] in Serum
# 106892    329-3  Metronidazole [Susceptibility] by Serum bacter...
# 101104  26221-2                                    Elbow - left MR
# 137412   5917-0                  Deprecated lead in dialysis fluid
# 40897   47333-0                      S pneum20 IgG sp2 Ser IA-mCnc
#
#                   source                                        text_normed
# 89637   LONG_COMMON_NAME   blackberry ige ab rast class [presence] in serum
# 106892  LONG_COMMON_NAME  metronidazole [susceptibility] by serum bacter...
# 101104  LONG_COMMON_NAME                                    elbow - left mr
# 137412  LONG_COMMON_NAME                  deprecated lead in dialysis fluid
# 40897          SHORTNAME                      s pneum20 igg sp2 ser ia-mcnc

# %%
df_merged_names.shape
# Out:
# (157577, 4)

# %% [markdown]
# ### Verify

# %%
df_merged_all[df_merged_all['label'] == '80659-6']
# Out:
#            label                                               text  \
# 2088251  80659-6                                      Point in time
# 2088246  80659-6                                          Clottable
# 2088248  80659-6                              Coagulation activated
# 2088243  80659-6                         Activated coagulation time
# 2088256  80659-6                                             Random
# 2088261  80659-6                                        Whole blood
# 2088250  80659-6                                   Coagulation time
# 77283    80659-6                            Activated clotting time
# 244037   80659-6  Activated clotting time (ACT) of Blood induced...
# 410791   80659-6                                               COAG
# 327414   80659-6                                                Bld
# 2088253  80659-6                                               Quan
# 2088241  80659-6                                                ACT
# 2088245  80659-6                                               Clot
# 2088259  80659-6                                          Tilt tube
# 2088258  80659-6                                             R-time
# 2088257  80659-6                                               Rate
# 2088249  80659-6                                  Coagulation assay
# 2088244  80659-6                                              Blood
# 2088242  80659-6                                              Activ
# 2088254  80659-6                                              Quant
# 2088252  80659-6                                                QNT
# 2088247  80659-6                                        COAGULATION
# 2088255  80659-6                                       Quantitative
# 2088260  80659-6                                                 WB
# 160660   80659-6                               ACT Bld Kaolin induc
#
#                    source                                        text_normed
# 2088251      RELATED_NAME                                      point in time
# 2088246      RELATED_NAME                                          clottable
# 2088248      RELATED_NAME                              coagulation activated
# 2088243      RELATED_NAME                         activated coagulation time
# 2088256      RELATED_NAME                                             random
# 2088261      RELATED_NAME                                        whole blood
# 2088250      RELATED_NAME                                   coagulation time
# 77283           COMPONENT                            activated clotting time
# 244037   LONG_COMMON_NAME  activated clotting time (act) of blood induced...
# 410791              CLASS                                               coag
# 327414             SYSTEM                                                bld
# 2088253      RELATED_NAME                                               quan
# 2088241      RELATED_NAME                                                act
# 2088245      RELATED_NAME                                               clot
# 2088259      RELATED_NAME                                          tilt tube
# 2088258      RELATED_NAME                                             r-time
# 2088257      RELATED_NAME                                               rate
# 2088249      RELATED_NAME                                  coagulation assay
# 2088244      RELATED_NAME                                              blood
# 2088242      RELATED_NAME                                              activ
# 2088254      RELATED_NAME                                              quant
# 2088252      RELATED_NAME                                                qnt
# 2088247      RELATED_NAME                                        coagulation
# 2088255      RELATED_NAME                                       quantitative
# 2088260      RELATED_NAME                                                 wb
# 160660          SHORTNAME                               act bld kaolin induc

# %%
df_merged_names[df_merged_names['label'] == '80659-6']
# Out:
#           label                                               text  \
# 77283   80659-6                               ACT Bld Kaolin induc
# 160660  80659-6  Activated clotting time (ACT) of Blood induced...
#
#                   source                                        text_normed
# 77283          SHORTNAME                               act bld kaolin induc
# 160660  LONG_COMMON_NAME  activated clotting time (act) of blood induced...

# %%
# Missing short name represented as NaN
df_short_name[df_short_name['LOINC_NUM'] == '72156-3']
# Out:
#       LOINC_NUM SHORTNAME
# 68050   72156-3       NaN

# %%
df_merged_names[df_merged_names['label'] == '72156-3']
# Out:
#           label                                     text            source  \
# 151427  72156-3  Rwandan maternal screening panel [RHEA]  LONG_COMMON_NAME
#
#                                     text_normed
# 151427  rwandan maternal screening panel [rhea]

# %% [markdown]
# ### Save

# %%
df_merged_all.to_csv('data/loinc-labeled-text-all.csv', index=False)
df_merged_names.to_csv('data/loinc-labeled-text-names.csv', index=False)
